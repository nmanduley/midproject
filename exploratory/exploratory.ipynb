# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
# confirmed_global
df_conf = pd.read_csv('confirmed_global.csv') 
df_conf.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/1/21  4/2/21  4/3/21  4/4/21  \
# 0        0        0        0        0  ...   56517   56572   56595   56676
# 1        0        0        0        0  ...  125506  125842  126183  126531
# 2        0        0        0        0  ...  117304  117429  117524  117622
# 3        0        0        0        0  ...   12053   12115   12174   12231
# 4        0        0        0        0  ...   22399   22467   22579   22631
#
#    4/5/21  4/6/21  4/7/21  4/8/21  4/9/21  4/10/21
# ...

# %%
# deaths_global
df_deaths = pd.read_csv('deaths_global.csv') 
df_deaths.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/1/21  4/2/21  4/3/21  4/4/21  \
# 0        0        0        0        0  ...    2489    2495    2496    2497
# 1        0        0        0        0  ...    2241    2247    2256    2265
# 2        0        0        0        0  ...    3096    3099    3102    3105
# 3        0        0        0        0  ...     115     116     117     117
# 4        0        0        0        0  ...     538     538     540     542
#
#    4/5/21  4/6/21  4/7/21  4/8/21  4/9/21  4/10/21
# ...

# %%
# recovered_global
df_rec = pd.read_csv('recovered_global.csv') 
df_rec.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  4/1/21  4/2/21  4/3/21  4/4/21  \
# 0        0        0        0        0  ...   51788   51798   51802   51885
# 1        0        0        0        0  ...   91875   92500   93173   93842
# 2        0        0        0        0  ...   81632   81729   81813   81896
# 3        0        0        0        0  ...   11365   11401   11428   11474
# 4        0        0        0        0  ...   20508   20867   20871   20879
#
#    4/5/21  4/6/21  4/7/21  4/8/21  4/9/21  4/10/21
# ...

# %% [markdown]
# ### Verificar NaN

# %%
# Hay confirmed_global, hay un valor Nan en "Lat" y "Long" correspondiente a Canada / Repatriated Travellers
df_conf[df_conf["Long"].isnull()]
# Out:
#             Province/State Country/Region  Lat  Long  1/22/20  1/23/20  \
# 52  Repatriated Travellers         Canada  NaN   NaN        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  4/1/21  4/2/21  4/3/21  4/4/21  \
# 52        0        0        0        0  ...      13      13      13      13
#
#     4/5/21  4/6/21  4/7/21  4/8/21  4/9/21  4/10/21
# 52      13      13      13      13      13       13
#
# [1 rows x 449 columns]

# %%
# En deaths_global tambien (y en recovered_global no)
df_deaths[df_deaths["Long"].isnull()]
# Out:
#             Province/State Country/Region  Lat  Long  1/22/20  1/23/20  \
# 52  Repatriated Travellers         Canada  NaN   NaN        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  4/1/21  4/2/21  4/3/21  4/4/21  \
# 52        0        0        0        0  ...       0       0       0       0
#
#     4/5/21  4/6/21  4/7/21  4/8/21  4/9/21  4/10/21
# 52       0       0       0       0       0        0
#
# [1 rows x 449 columns]

# %%
# Como es una porcion minuscula de casos, esta fila sera suprimida
df_rec[df_rec["Lat"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Province/State, Country/Region, Lat, Long, 1/22/20, 1/23/20, 1/24/20, 1/25/20, 1/26/20, 1/27/20, 1/28/20, 1/29/20, 1/30/20, 1/31/20, 2/1/20, 2/2/20, 2/3/20, 2/4/20, 2/5/20, 2/6/20, 2/7/20, 2/8/20, 2/9/20, 2/10/20, 2/11/20, 2/12/20, 2/13/20, 2/14/20, 2/15/20, 2/16/20, 2/17/20, 2/18/20, 2/19/20, 2/20/20, 2/21/20, 2/22/20, 2/23/20, 2/24/20, 2/25/20, 2/26/20, 2/27/20, 2/28/20, 2/29/20, 3/1/20, 3/2/20, 3/3/20, 3/4/20, 3/5/20, 3/6/20, 3/7/20, 3/8/20, 3/9/20, 3/10/20, 3/11/20, 3/12/20, 3/13/20, 3/14/20, 3/15/20, 3/16/20, 3/17/20, 3/18/20, 3/19/20, 3/20/20, 3/21/20, 3/22/20, 3/23/20, 3/24/20, 3/25/20, 3/26/20, 3/27/20, 3/28/20, 3/29/20, 3/30/20, 3/31/20, 4/1/20, 4/2/20, 4/3/20, 4/4/20, 4/5/20, 4/6/20, 4/7/20, 4/8/20, 4/9/20, 4/10/20, 4/11/20, 4/12/20, 4/13/20, 4/14/20, 4/15/20, 4/16/20, 4/17/20, 4/18/20, 4/19/20, 4/20/20, 4/21/20, 4/22/20, 4/23/20, 4/24/20, 4/25/20, 4/26/20, ...]
# Index: []
#
# [0 rows x 449 columns]

# %%
# En recovered_global hay una sola entrada para Canada
df_rec[df_rec["Country/Region"] == "Canada"]
# Out:
#    Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 39            NaN         Canada  56.1304 -106.3468        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  4/1/21  4/2/21  4/3/21  4/4/21  \
# 39        0        0        0        0  ...  922632  924144  929085  930750
#
#     4/5/21  4/6/21  4/7/21  4/8/21  4/9/21  4/10/21
# 39  937403  945550  950990  956665  962451   967364
#
# [1 rows x 449 columns]

# %%
# NaN por columna:
df_conf.isnull().sum()
# En el preview aparecen 189 valores NaN en la columna Province/State, y 1 en Lat y Long.
# Haciendo .sum() de lo anterior, el total de NaN en el dataset da 191. Por lo tanto, no hay NaN en las columnas de fechas.
# Ocurre algo similar con los tres datasets. Por lo tanto, solo hace falta lidiar con los NaN de la columna de provincias, y los de Lat y Long.
# Out:
# Province/State    189
# Country/Region      0
# Lat                 1
# Long                1
# 1/22/20             0
#                  ...
# 4/6/21              0
# 4/7/21              0
# 4/8/21              0
# 4/9/21              0
# 4/10/21             0
# Length: 449, dtype: int64

# %% [markdown]
# ### Para mayor manejabilidad, los paises cuyas estadisticas estén especificadas por provincia seran integrados en una sola fila, y la columna "Province/State" sera desechada

# %%
# Confirmed
grouped_conf = df_conf.groupby('Country/Region').sum().reset_index()

# Deaths
grouped_deaths = df_deaths.groupby('Country/Region').sum().reset_index()

# Recovered
grouped_rec = df_rec.groupby('Country/Region').sum().reset_index()

# %% [markdown]
# ### Exportar nuevos CSV

# %%
grouped_conf.to_csv('grouped_confirmed.csv', index=False)
grouped_deaths.to_csv('grouped_deaths.csv', index=False)
grouped_rec.to_csv('grouped_recovered.csv', index=False)

# %% [markdown]
# ### Visualizacion

# %%
data.iloc[0,4:]
# Out:
# 1/22/20          0
# 1/23/20          0
# 1/24/20          0
# 1/25/20          0
# 1/26/20          0
#             ...
# 4/6/21     3317948
# 4/7/21     3326736
# 4/8/21     3336637
# 4/9/21     3347512
# 4/10/21    3347512
# Name: 233, Length: 445, dtype: object

# %%
country = "Spain"
data = df_conf[df_conf["Country/Region"]==country]

xvals = [datetime.strptime(col_name, '%m/%d/%y') for col_name in data.columns[4:]]

fig = plt.figure(figsize=(10,5))
plt.plot(xvals, data.iloc[0,4:])
plt.grid('minor')
plt.title(f"Total confirmed deaths in {country}")
# Out:
# Text(0.5, 1.0, 'Total confirmed deaths in Spain')

# %%
countries = ["Spain", "Panama", "Venezuela", "Colombia"]

fig = plt.figure(figsize=(10,5))
for country in countries:
    data = df_conf[df_conf["Country/Region"]==country]
    xvals = [datetime.strptime(col_name, '%m/%d/%y') for col_name in data.columns[4:]]
    
    plt.plot(xvals, data.iloc[0,4:])
    plt.grid('minor')

    country_lst = ', '.join(countries)
plt.title(f"Total confirmed deaths in {country_lst}")
plt.legend(countries)
