# %%
from pymongo import MongoClient
from dotenv import load_dotenv
import os
load_dotenv()

client = MongoClient(os.getenv("url"))
covid = client.get_database("covid")
confirmed_global = covid["confirmed_global"]
deaths_global = covid["deaths_global"]
recovered_global = covid["recovered_global"]

# %%
cur = confirmed_global.find({})
res = list(cur)
res[0]
# Out:
# {'_id': ObjectId('636d331038e51f9c54c76ad1'),
#  'Country/Region': 'Afghanistan',
#  'Lat': '33.93911',
#  'Long': '67.709953',
#  '1/22/20': '0',
#  '1/23/20': '0',
#  '1/24/20': '0',
#  '1/25/20': '0',
#  '1/26/20': '0',
#  '1/27/20': '0',
#  '1/28/20': '0',
#  '1/29/20': '0',
#  '1/30/20': '0',
#  '1/31/20': '0',
#  '2/1/20': '0',
#  '2/2/20': '0',
#  '2/3/20': '0',
#  '2/4/20': '0',
#  '2/5/20': '0',
#  '2/6/20': '0',
#  '2/7/20': '0',
#  '2/8/20': '0',
#  '2/9/20': '0',
#  '2/10/20': '0',
#  '2/11/20': '0',
#  '2/12/20': '0',
#  '2/13/20': '0',
#  '2/14/20': '0',
#  '2/15/20': '0',
#  '2/16/20': '0',
#  '2/17/20': '0',
#  '2/18/20': '0',
#  '2/19/20': '0',
#  '2/20/20': '0',
#  '2/21/20': '0',
#  '2/22/20': '0',
#  '2/23/20': '0',
#  '2/24/20': '1',
#  '2/25/20': '1',
#  '2/26/20': '1',
#  '2/27/20': '1',
#  '2/28/20': '1',
#  '2/29/20': '1',
#  '3/1/20': '1',
#  '3/2/20': '1',
#  '3/3/20': '2',
#  '3/4/20': '4',
#  '3/5/20': '4',
#  '3/6/20': '4',
#  '3/7/20': '4',
# ...

# %%
# Get all dates for a single country
country = "Spain"
filt = {"Country/Region":country}
project = {"Country/Region":0, "Lat":0, "Long":0, "_id":0}
dates = confirmed_global.find(filt, project)
dates = list(dates)[0]
dates_vals = list(dates.values())
dates_keys = list(dates.keys())
dates_keys
# Out:
# ['1/22/20',
#  '1/23/20',
#  '1/24/20',
#  '1/25/20',
#  '1/26/20',
#  '1/27/20',
#  '1/28/20',
#  '1/29/20',
#  '1/30/20',
#  '1/31/20',
#  '2/1/20',
#  '2/2/20',
#  '2/3/20',
#  '2/4/20',
#  '2/5/20',
#  '2/6/20',
#  '2/7/20',
#  '2/8/20',
#  '2/9/20',
#  '2/10/20',
#  '2/11/20',
#  '2/12/20',
#  '2/13/20',
#  '2/14/20',
#  '2/15/20',
#  '2/16/20',
#  '2/17/20',
#  '2/18/20',
#  '2/19/20',
#  '2/20/20',
#  '2/21/20',
#  '2/22/20',
#  '2/23/20',
#  '2/24/20',
#  '2/25/20',
#  '2/26/20',
#  '2/27/20',
#  '2/28/20',
#  '2/29/20',
#  '3/1/20',
#  '3/2/20',
#  '3/3/20',
#  '3/4/20',
#  '3/5/20',
#  '3/6/20',
#  '3/7/20',
#  '3/8/20',
#  '3/9/20',
#  '3/10/20',
#  '3/11/20',
#  '3/12/20',
#  '3/13/20',
#  '3/14/20',
#  '3/15/20',
#  '3/16/20',
#  '3/17/20',
#  '3/18/20',
#  '3/19/20',
#  '3/20/20',
#  '3/21/20',
#  '3/22/20',
#  '3/23/20',
#  '3/24/20',
#  '3/25/20',
#  '3/26/20',
#  '3/27/20',
#  '3/28/20',
#  '3/29/20',
#  '3/30/20',
#  '3/31/20',
#  '4/1/20',
#  '4/2/20',
# ...

# %%
# # Regex: find date format
# date_format = "[0-9]{1,2}+\/+[0-9]{1,2}+\/[0-9]{2}"
# dates = re.findall(date_format, keys_list)

# %%
# def get_country_all_data_date(db, country, date):
#     if type(date)==str:
#         date = datetime.strptime(date,"%m/%d/%y")
#     else:
#         date=date
    
#     filt = {"Country/Region": country, "Date": date}
#     project = {"Country/Region":1,"Date":1,"Cases":1,"Deaths":1,"Recovered":1,"_id":0}
#     results = list(db.find(filt, project))
#     return results
